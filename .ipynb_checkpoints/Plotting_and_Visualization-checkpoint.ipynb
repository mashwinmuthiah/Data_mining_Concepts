# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
data = np.arange(10)
plt.rc('figure',figsize = (5,5))

# %%
import matplotlib.pyplot as plt
plt.plot(data)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randint(1,50,20),'k--')
ax1.plot(data)
ax2.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig , axes = plt.subplots(2,3,sharex=True)
axes[0,0].plot(data)
axes[1,1].hist(np.random.randn(50))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([3., 6., 7., 7., 9., 7., 6., 2., 2., 1.]),
#  array([-1.52736433, -1.15891086, -0.79045739, -0.42200392, -0.05355045,
#          0.31490303,  0.6833565 ,  1.05180997,  1.42026344,  1.78871691,
#          2.15717039]),
#  <a list of 10 Patch objects>)

# %%
fig , axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.rand(500),bins = 50 ,color='k',alpha = .5)
plt.subplots_adjust(wspace = 0,hspace = 0)

# %%
plt.plot(np.random.randint(0,50,30),linestyle = '--', color = 'r',marker = 'o')

# %%
data = np.random.rand(50)
plt.plot(data,'ro--',label='Default')
plt.plot(data,drawstyle = 'steps-post',label = 'steps-post')
plt.legend(loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0,100,200,300,400,500,600,700,800,900,1000])
ax.set_xticklabels(['a','b','c','d','e','f','g','h','i','j','k'],rotation = 30,fontsize=12)
ax.set_title('My first matplotlib plot')
ax.set_xlabel("Stages")
# Out:
# Text(0.5,0,'Stages')

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000])
# Out:
# ([<matplotlib.axis.XTick at 0x193b933b320>,
#   <matplotlib.axis.XTick at 0x193b92d2be0>,
#   <matplotlib.axis.XTick at 0x193b92d3c18>,
#   <matplotlib.axis.XTick at 0x193b92d37f0>,
#   <matplotlib.axis.XTick at 0x193b92d3240>,
#   <matplotlib.axis.XTick at 0x193b92c3588>,
#   <matplotlib.axis.XTick at 0x193b9327400>,
#   <matplotlib.axis.XTick at 0x193b9327668>,
#   <matplotlib.axis.XTick at 0x193b92f9438>,
#   <matplotlib.axis.XTick at 0x193b92f9208>,
#   <matplotlib.axis.XTick at 0x193b926bf28>],
#  <a list of 11 Text xticklabel objects>)

# %%
from numpy.random import randn
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc = 'best')

# %%
plt.legend?

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv(r'C:\Users\ashwi\Desktop\Ashwin\pydata-book\examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5,1,'Important dates in the 2008-2009 financial crisis')

# %%
lab = ['1','6','3','5','8','1','3','9']
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot([1,6,3,5,8,1,3,9])

for i,j in enumerate([1,6,3,5,8,1,3,9]):
    ax.annotate(lab[i],xy = (i,j),xytext = (i,j+1),arrowprops = dict(facecolor='red',edgecolor = 'blue', headwidth=4, width=2,
                                headlength=4))
plt.savefig(r'C:\Users\ashwi\Desktop\Ashwin\data_mining_concepts\check.pdf')
